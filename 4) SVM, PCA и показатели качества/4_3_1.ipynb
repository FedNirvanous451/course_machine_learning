# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../img/4_3_1.png')  # Загрузите изображение, указав путь к файлу.
plt.imshow(img)  # Отобразите изображение.
plt.axis('off')  # Отключите отображение осей.
plt.show()

# %%
import numpy as np
from sklearn import svm


def func(x):
    return np.sin(0.5*x) + 0.2 * np.cos(2*x) - 0.1 * np.sin(4 * x) + 3


# обучающая выборка
coord_x = np.expand_dims(np.arange(-4.0, 6.0, 0.1), axis=1)
coord_y = func(coord_x).ravel()

svr = svm.SVR(kernel='rbf')    # SVM с нелинейным ядром
x_train = coord_x[::3]
y_train = coord_y[::3]
svr.fit(x_train, y_train)
predict = svr.predict(coord_x)
Q = np.mean((predict - y_train.T) ** 2)
Q, predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 18
#      16 svr.fit(x_train, y_train)
#      17 predict = svr.predict(coord_x)
# ---> 18 Q = np.mean((predict.T - y_train) ** 2)
#      19 Q, predict
#
# ValueError: operands could not be broadcast together with shapes (100,) (34,)
