# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../img/4_7_1.png')  # Загрузите изображение, указав путь к файлу.
plt.imshow(img)  # Отобразите изображение.
plt.axis('off')  # Отключите отображение осей.
plt.show()

# %%
import numpy as np

np.random.seed(0)

# исходные параметры для формирования образов обучающей выборки
r = 0.7
D = 3.0
mean = [3, 7, -2, 4, 6]
n_feature = 5
V = [[D * r ** abs(i-j) for j in range(n_feature)] for i in range(n_feature)]

# моделирование обучающей выборки
N = 1000
X = np.random.multivariate_normal(mean, V, N).T

F = (1 / N) * X @ X.T # формула для вычисления матрицы Грама, далее сможем вычислить собственные векторы и собственные числа
L, W = np.linalg.eig(F) # L - собственные числа, W - собственные векторы
L, W, F
# Out:
# (array([121.97087918,   4.65931132,   2.65089954,   1.01874301,
#           0.73233795]),
#  array([[-0.29681658, -0.22479594,  0.55492499,  0.73859524, -0.08889331],
#         [-0.65500922,  0.00277807,  0.45638698, -0.59194603,  0.11075205],
#         [ 0.14340159, -0.92536417, -0.05386004, -0.14567391,  0.31466704],
#         [-0.38793169, -0.2938037 , -0.40838809, -0.03135558, -0.77163747],
#         [-0.55839755,  0.08270195, -0.56043504,  0.2861344 ,  0.53422115]]),
#  array([[ 12.35895175,  23.9291307 ,  -4.43167014,  13.77789234,
#           19.48512592],
#         [ 23.9291307 ,  53.24816975, -11.4204177 ,  30.45109577,
#           43.80533989],
#         [ -4.43167014, -11.4204177 ,   6.59979547,  -5.63334686,
#           -9.96274324],
#         [ 13.77789234,  30.45109577,  -5.63334686,  19.63688687,
#           26.60382879],
#         [ 19.48512592,  43.80533989,  -9.96274324,  26.60382879,
#           39.18836716]]))
