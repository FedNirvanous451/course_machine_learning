# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../img/3_4_2.png')  # Загрузите изображение, указав путь к файлу.
plt.imshow(img)  # Отобразите изображение.
plt.axis('off')  # Отключите отображение осей.
plt.show()

# %%
import numpy as np


def func(x):
    return 0.5 * x + 0.2 * x ** 2 - 0.05 * x ** 3 + 0.2 * np.sin(4 * x) - 2.5


def model(w, x):
    return w[0] + w[1] * x + w[2] * x ** 2 + w[3] * x ** 3

coord_x = np.arange(-4.0, 6.0, 0.1)

x_train = np.array([[_x**i for i in range(4)] for _x in coord_x]) # обучающая выборка
y_train = func(coord_x) # целевые выходные значения

print(x_train, y_train)
"""
дорешать
for i in range(len(y_train)):
    w = gaussian(x_train, y_train.T)
print(w)"""
# Out:
# [[ 1.00000000e+00 -4.00000000e+00  1.60000000e+01 -6.40000000e+01]
#  [ 1.00000000e+00 -3.90000000e+00  1.52100000e+01 -5.93190000e+01]
#  [ 1.00000000e+00 -3.80000000e+00  1.44400000e+01 -5.48720000e+01]
#  [ 1.00000000e+00 -3.70000000e+00  1.36900000e+01 -5.06530000e+01]
#  [ 1.00000000e+00 -3.60000000e+00  1.29600000e+01 -4.66560000e+01]
#  [ 1.00000000e+00 -3.50000000e+00  1.22500000e+01 -4.28750000e+01]
#  [ 1.00000000e+00 -3.40000000e+00  1.15600000e+01 -3.93040000e+01]
#  [ 1.00000000e+00 -3.30000000e+00  1.08900000e+01 -3.59370000e+01]
#  [ 1.00000000e+00 -3.20000000e+00  1.02400000e+01 -3.27680000e+01]
#  [ 1.00000000e+00 -3.10000000e+00  9.61000000e+00 -2.97910000e+01]
#  [ 1.00000000e+00 -3.00000000e+00  9.00000000e+00 -2.70000000e+01]
#  [ 1.00000000e+00 -2.90000000e+00  8.41000000e+00 -2.43890000e+01]
#  [ 1.00000000e+00 -2.80000000e+00  7.84000000e+00 -2.19520000e+01]
#  [ 1.00000000e+00 -2.70000000e+00  7.29000000e+00 -1.96830000e+01]
# ...
