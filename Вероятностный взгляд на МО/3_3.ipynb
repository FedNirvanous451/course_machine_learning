# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../img/3_3.png')  # Загрузите изображение, указав путь к файлу.
plt.imshow(img)  # Отобразите изображение.
plt.axis('off')  # Отключите отображение осей.
plt.show()

# %%
print(1/3 * (1/2) / (1/3*1/2 + 1/3*1/3 + 1/3*1/4))

# место, которое я не понимал: каким образом считать вероятность p(b) - выбор питона
# надо просто выбрать питон в каждом варианте и сложить - рассматриваем все возможные варианты и все
# Out:
# 0.4615384615384615

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../img/3_3_1.png')  # Загрузите изображение, указав путь к файлу.
plt.imshow(img)  # Отобразите изображение.
plt.axis('off')  # Отключите отображение осей.
plt.show()

# %%
print(0.2*0.9/(0.9*0.2 + 0.3*0.2+0.1*0.3))
# Out:
# 0.6666666666666667

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('../img/3_3_2.png')  # Загрузите изображение, указав путь к файлу.
plt.imshow(img)  # Отобразите изображение.
plt.axis('off')  # Отключите отображение осей.
plt.show()

# %%
# путем мат. преобразований получим выражение для нахождения x
# подберем х с помощью цикла
